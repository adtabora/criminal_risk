# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
# Out:
# /Users/alextabora/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
documents_df = pd.read_csv("../files/documents.csv")
print documents_df.shape
# Out:
# (2500, 5)

# %%
for index, row in documents_df[documents_df["category"] == "Criminal"].iterrows():
    print str(index) + "  "+row["title"]
# Out:
# 3  Citan a 11 personas por vender pólvora
# 5  DEI pide denunciar empleados que hicieron cobro ilegal en aduanas
# 9  Alcaldía intensifica operativos tras pólvora trasegada a la capital
# 11  Pasajeros asaltantes acribillan a un taxista
# 12  Fallece comerciante olanchano víctima de atentado criminal
# 13  Por venganza mataron a pareja en El Negrito
# 16  Campesinos hieren a guardia al invadir finca de palma africana
# 20  Cae banda de asaltantes tras robo en Valle de Ángeles
# 24  Asesinan a ex presidente de la Andep en su casa
# 30  Andaba en malos pasos
# 31  Policía cae junto a banda tras haber asaltado un banco
# 32  Falsos policías matan a una mujer y su hijo
# 33  Valiente pasajero perece al tratar de frustrar asalto
# 34  Apresan dos personas con una tonelada de cohetes
# 35  Menor es ultimado supuestamente por invasores de tierras
# 46  Cae policía por robo de café
# 54  “Enloquecido” masacra a tres hombres de varios machetazos
# 55  Hombre le saca un ojo a su esposa de un balazo
# 56  Madre de niño ultimado por invasores clama justicia
# 63  Decomisan casi 53 kilos de pseudoefedrina
# 66  “El Chapo” montó un imperio de 288 empresas en más de una decena de países
# 78  Capturan banda que secuestró a una mujer
# 79  Caen pandilleros tras matar comerciante
# 92  Dos cobradores se salvan de las garras de la muerte
# 109  Marlon Escoto:  “Maestros y padres de familia deben tener responsabilidad compartida”
# 162  Policía frustra robo de cajero automático en la zona norte de Honduras
# 170  Extorsionadores están reteniendo a niños hondureños para cobrar impuesto de guerra
# 188  PM y Preventiva recuperaron unas 50 viviendas que tenían maleantes
# 190  Estrangulan mujer y la dejan cerca de carretera
# 192  Dos indigentes muertos a balazos
# 193  Seis mujeres fueron ultimadas en la reciente semana
# 194  Rápida acción policial frustra robo de cajeros
# 197  Caen tres pandilleros con 50 mil lempiras
# 198  Condenan a 40 años de cárcel a 8 pandilleros por crimen de joven deportista.
# 237  VUELVEN FEMICIDIOS
# 269  El director del Infah, aseguró que se le está dando seguimiento a los casos de menores involucrados en el delito de extorsión.
# 277  Autoridades hondureñas,  investigarán la muerte de un centenar de campesinos en los últimos cuatro años.
# 301  Incautan en Bogotá más de una tonelada de marihuana atribuida a las FARC
# 320  Motociclistas ultiman a coronel retirado
# 321  Capturado con granada tenía dos órdenes de captura por homicidio
# 353  Siete agentes suspendidos por muerte de mujer en posta policial
# 380  15 bandas se dedican a clonar tarjetas
# 381  Le quitan la vida a una ama de casa
# 387  En enfrentamiento cae banda de Los Marines
# 388  Pistoleros acabaron con la vida de dos hombres
# 389  Ejecutan a comerciante y lo lanzan en crique
# 390  Cinco pandilleros de la 18 mueren en un enfrentamiento con la Policía
# 394  ¡Golpe al tráfico de armas!
# 399  Terror en Santa Bárbara
# 434  A investigación siete uniformados por deceso de una mujer al interior de posta policial
# 441  Autoridades definirán si hubo delito en muerte de magistrado en Guatemala
# 443  Autoridades incautan un camión con armas y municiones en el norte de Honduras
# 445  Al menos 29 muertos en un nuevo ataque de Boko Haram en Nigeria
# 469  Acribillan a motorista y pasajero de “rapidito”
# 2230  Estrangulan a tres reos en el Centro Penal de San Pedro Sula
# 2233  Apresan muchacha que llevaba “moña” a presos
# 2236  MATONES DE LA CENTRALISTA
# 2247  Liquidan a hijo de un exregidor
# 2257  Encostalan mujer y la botan en una vivienda abandonada
# 2272  Ultiman a tiros a dos hombres en Choloma
# 2276  Autoridades colombianas recapturan presunto asesino fugado y admiten errores
# 2286  Arrestan a mujer que estafó a unas 500 personas
# 2298  Un muerto y un herido en un tiroteo ante la Agencia de Seguridad de EE.UU.
# 2299  Asesinan a tres trabajadores agrícolas nicaragüenses en Costa Rica
# 2303  Joven decapita novia y se entrega con la cabeza de la víctima en Brasil
# 2306  DEI detecta en Toncontín mercadería irregular procedente de Panamá
# 2308  Detención judicial para supuestos homicidas de centralista
# 2320  Sale al encuentro de su esposa y halla la muerte
# 2321  Hipótesis: Compinches matan pandilleros por traidores
# 2322  Cae pareja con chimba y puchos de marihuana
# 2323  Policía Militar captura a despachador de buses por extorsionar a compañeros
# 2350  Rosario de delitos pagaban estrangulados en Támara
# 2378  Detenido en Costa Rica italiano que ingirió 101 óvulos de cocaína
# 2379  Hombres armados secuestran a un fiscal en tribunal de Estambul
# 2381  DNIC recupera tres vehículos robados en Tegucigalpa
# 2382  Hombre asesinado en Esparta
# 2395  Guatemala extradita a México a líder de Los Zetas condenado por matanza 2008
# 2397  La policía turca abate a dos supuestos secuestradores, el fiscal está herido
# 2405  Policía mexicana captura a uno de los presuntos asesinos de 72 migrantes
# 2407  Asaltante mata a pasajero de “rapidito” en la capital
# 2410  Caen cuatro menores que portaban arma y munición
# 2415  Capturan italiano con más de 10 mil dólares
# 2420  Rescatan en costas de Tela a norteamericanos raptados por piratas
# 2422  26 menores infractoras casi queman correccional
# 2426  Capturan a supuestos homicidas de pasajero de bus en Tegucigalpa
# 2474  Detenidos supuestos antisociales en Chamelecón
# 2475  Capturan a cuatro supuestos extorsionadores
# 2485  Tres heridos deja balacera en Tocoa

# %% [markdown]
# # Category Distribution

# %%
x = documents_df.category.value_counts()
print x

# sns.distplot(x,bins=10)
# sns.barplot( x.index,x, palette="BuGn_d", )
fig1, ax1 = plt.subplots()

ax1.pie(x, labels=x.index, autopct='%1.1f%%', shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# sns.piechart( x.index,x, palette="BuGn_d", )
plt.show()
# Out:
# Other       2191
# Criminal     309
# Name: category, dtype: int64

# %%
documents_df.loc[:,"Empty Content"] =  documents_df.content.isnull()

result = documents_df.groupby(by=["category","Empty Content"])["id"].count().reset_index(["category","Empty Content"])
print result
g = sns.factorplot(x="category",y="id", hue="Empty Content", data=result,
                   size=6, kind="bar", palette="muted")
plt.show()
# g.despine(left=True)
# g.set_ylabels("survival probability")

# documents_df = documents_df[(documents_df.content.notnull() ) & (documents_df["category"]!="Criminal-Other")]
# Out:
#    category Empty Content    id
# 0  Criminal         False   292
# 1  Criminal          True    17
# 2     Other         False  1897
# 3     Other          True   294

# %% [markdown]
# # Content Length by Category

# %%
documents_df.loc[:,"content_size"] = documents_df.content.apply(lambda x: len(x) if type(x)==str else 0)
documents_df.groupby(by="category").content_size.mean()
# Out:
# category
# Criminal    1568.517799
# Other       1786.422638
# Name: content_size, dtype: float64

# %%
sns.distplot( documents_df[documents_df["category"]=="Other"].content_size, color = 'b'  )
sns.distplot( documents_df[documents_df["category"]=="Criminal"].content_size , color='r' )
plt.show()

# %% [markdown]
# # Title Size by Category

# %%
documents_df.loc[:,"title_size"] = documents_df.title.apply(lambda x: len(x))
documents_df.groupby(by="category").title_size.mean()
# Out:
# category
# Criminal    55.559871
# Other       54.564126
# Name: title_size, dtype: float64

# %%
sns.distplot( documents_df[documents_df["category"]=="Other"].title_size, color = 'b'  )
sns.distplot( documents_df[documents_df["category"]=="Criminal"].title_size , color='r' )
plt.show()

# %% [markdown]
# # Word Analysis

# %%
import nltk
from nltk import wordpunct_tokenize, RegexpTokenizer
stop_words = pd.read_json("../files/stopwords.json")[0].values.tolist()

# %% [markdown]
# # Common Content Words

# %%
#recompile the whole text for vocabulary
full_text = ""
for index, row in documents_df.iterrows():
    full_text += " " + row["content"]
    
criminal_text = ""
for index, row in documents_df[documents_df["category"] == "Criminal"].iterrows():
    criminal_text += " " + row["content"]   
    
other_text = ""
for index, row in documents_df[documents_df["category"] == "Other"].iterrows():
    other_text += " " + row["content"]   
    
# get the most common words    
regTokenizer = RegexpTokenizer(r'\w+')#RegexpTokenizer(r'\w+')
def most_common(text,top=30):
    tokens = regTokenizer.tokenize( unicode(text, "utf-8").lower() )
    tokens = [ token for token in tokens if token not in stop_words]

    fdist = nltk.FreqDist(tokens)
    for w in  fdist.most_common(top):
        print w
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-eb3d85c26861> in <module>()
#       2 full_text = ""
#       3 for index, row in documents_df.iterrows():
# ----> 4     full_text += " " + row["content"]
#       5
#       6 criminal_text = ""
#
# TypeError: cannot concatenate 'str' and 'float' objects

# %%
most_common(criminal_text,30)

# %%
most_common(other_text,30)

# %%
from wordcloud import WordCloud
regTokenizer = RegexpTokenizer(r'\w+')
tokens = regTokenizer.tokenize( unicode(criminal_text, "utf-8").lower() )
tokens = [ token for token in tokens if token not in stop_words]
text = " ".join(tokens)
wordcloud = WordCloud(background_color="white",
                      max_font_size=40, relative_scaling=.9).generate(text )

plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
regTokenizer = RegexpTokenizer(r'\w+')
tokens = regTokenizer.tokenize( unicode(other_text, "utf-8").lower() )
tokens = [ token for token in tokens if token not in stop_words]
text = " ".join(tokens)
wordcloud = WordCloud(background_color="white",
                      max_font_size=40, relative_scaling=.9).generate(text )

plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# # TITLE

# %%
#recompile the whole text for vocabulary
criminal_titles = ""
for index, row in documents_df[documents_df["category"] == "Criminal"].iterrows():
    criminal_titles += " " + row["title"]   
    
other_titles = ""
for index, row in documents_df[documents_df["category"] == "Other"].iterrows():
    other_titles += " " + row["title"]

# %%
for index, row in documents_df[documents_df["category"] == "Criminal"].iterrows():
    print str(index) + "  "+row["title"]

# %%
regTokenizer = RegexpTokenizer(r'\w+')
tokens = regTokenizer.tokenize( unicode(criminal_titles, "utf-8").lower() )
tokens = [ token for token in tokens if token not in stop_words]
text = " ".join(tokens)
wordcloud = WordCloud(background_color="white",
                      max_font_size=40, relative_scaling=.9).generate(text )

plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
regTokenizer = RegexpTokenizer(r'\w+')
tokens = regTokenizer.tokenize( unicode(other_titles, "utf-8").lower() )
tokens = [ token for token in tokens if token not in stop_words]
text = " ".join(tokens)
wordcloud = WordCloud(background_color="white",
                      max_font_size=40, relative_scaling=.8).generate(text )

plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
