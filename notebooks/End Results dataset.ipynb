# %% [markdown]
# # Intro
#
# This notebook is to generate the end result labels (i.e. the addresses that will be used in the google maps api).The generated dataset will be used to test/score the end-to-end pipeline. The input are the entities and relationships that are labeled in the criminal articles dataset.

# %%
import pandas as pd
import numpy as np
import ast 
import unicodedata

# %%
articles = pd.read_csv("../files/criminal_articles.csv")
articles.head()
# Out:
#    article_id                                              title  \
# 0           3  [[u'Citan', u'none'], [u'a', u'none'], [u'11',...
# 1           5  [[u'DEI', u'none'], [u'pide', u'none'], [u'den...
# 2           9  [[u'Alcald\xeda', u'none'], [u'intensifica', u...
# 3          11  [[u'Pasajeros', u'none'], [u'asaltantes', u'no...
# 4          12  [[u'Fallece', u'none'], [u'comerciante', u'non...
#
#                                              content  \
# 0  [[[u'SAN', u'B-City'], [u'PEDRO', u'I-City'], ...
# 1  [[[u'TEGUCIGALPA', u'B-City']], [[u'-', u'none...
# 2  [[[u'TEGUCIGALPA', u'B-City']], [[u'-', u'none...
# 3  [[[u'PUERTO', u'B-City'], [u'CORTES', u'I-City...
# 4  [[[u'JUTICALPA', u'B-City'], [u',', u'none'], ...
#
#                                        relationships
# 0  [[{u'tag': u'B-Col', u'word': u'lomas del carm...
# 1                                                 []
# 2  [[{u'tag': u'B-Col', u'word': u'kennedy'}, {u'...
# 3  [[{u'tag': u'B-City', u'word': u'puerto cortes...
# 4  [[{u'tag': u'B-City', u'word': u'juticalpa'}, ...

# %% [markdown]
# # preprocess

# %%
# very useful functions to avoid mispellings problems.
# you'll thank me later
def to_ascii(s):
    return unicodedata.normalize('NFKD', s).encode('ascii', 'ignore')

def sent_to_ascii(sentences):
    for sent_ix, sent in enumerate(sentences):
        for word_ix, word in enumerate(sent):
            sentences[sent_ix][word_ix][0] =  to_ascii(word[0])
    return sentences
            
def rel_to_ascii(relationships):
    for rel_ix, rel in enumerate(relationships):
        relationships[rel_ix][0]["word"] = to_ascii(relationships[rel_ix][0]["word"])
        relationships[rel_ix][1]["word"] = to_ascii(relationships[rel_ix][1]["word"])
    return relationships

# %%
# convert string into array
articles.loc[:,"title"] = articles.title.apply(lambda x: ast.literal_eval(x) )
articles.loc[:,"content"] = articles.content.apply(lambda x: ast.literal_eval(x) )
articles.loc[:,"relationships"] = articles.relationships.apply(lambda x: ast.literal_eval(x) )
#convert to ascii
articles.title = articles.title.apply(lambda x: sent_to_ascii([x]) if x != None else x )
articles.content = articles.content.apply(lambda x: sent_to_ascii(x) if x != None else x )
articles.relationships = articles.relationships.apply(lambda x: rel_to_ascii(x) if x != None else x )

# get all the full text
articles.loc[:,"full_text"] = articles.title.apply(lambda x: x) + articles.content

# %%
# format relationships
def format_relationship_tags(relationships):

    for ix, rel in enumerate(relationships):
        relationships[ix][0]["tag"] = rel[0]["tag"][2:]
        relationships[ix][1]["tag"] = rel[1]["tag"][2:]
    return relationships

articles.relationships.apply(lambda x: format_relationship_tags(x))
articles.relationships.head()
# Out:
# 0    [[{u'tag': u'Col', u'word': u'lomas del carmen...
# 1                                                   []
# 2    [[{u'tag': u'Col', u'word': u'kennedy'}, {u'ta...
# 3    [[{u'tag': u'City', u'word': u'puerto cortes'}...
# 4    [[{u'tag': u'City', u'word': u'juticalpa'}, {u...
# Name: relationships, dtype: object

# %% [markdown]
# # Extract Entities

# %%
def getEntities(content):
    entities = []
    for sent in content:
        for word in sent:
            if word[1][0] == "B":
                entities.append({"word": word[0].lower(),"tag":word[1][2:]})
            elif word[1][0] == "I":
                entities[-1]["word"] += " " + word[0].lower()
                
    #eliminate duplicates
    unique_entities = []
    for itm in entities:
        if itm not in unique_entities:
            unique_entities.append(itm)
                
    return unique_entities

# %%
articles.loc[:,"entities"] = articles.full_text.apply(lambda x: getEntities(x))

# %%
#change some entities that are equivalent
def entity_equivalencies(entities):
    eq_map = {
        "comayaguela":"tegucigalpa",
        "distrito central":"tegucigalpa",
        "eeuu":"estados unidos",
        "ee.uu.":"estados unidos",
        "ee. uu.":"estados unidos",
    }
    for idx, entity in enumerate(entities):
        if entity in eq_map:
            entities[idx] = eq_map[entity]
            
    return entities

def rel_equivalencies(relationships):
    eq_map = {
        "comayaguela":"tegucigalpa",
        "distrito central":"tegucigalpa",
        "eeuu":"estados unidos",
        "ee.uu.":"estados unidos",
        "ee. uu.":"estados unidos",
    }
    
    for rel_idx, rel in enumerate(relationships):
        if rel[0]["word"] in eq_map:
            relationships[rel_idx][0]["word"] = eq_map[rel[0]["word"]]
        if rel[1]["word"] in eq_map:
            relationships[rel_idx][1]["word"] = eq_map[rel[1]["word"]]
            
    return relationships
    
    
            


# articles.loc[:,"entities"] = articles.entities.apply(lambda x: eq_map[x] if x in eq_map else x)
    
for _, article  in articles.loc[:10].iterrows():
    print article.entities
# Out:
# [{'tag': u'City', 'word': 'san pedro sula'}, {'tag': u'Col', 'word': 'lomas del carmen'}, {'tag': u'Zone', 'word': 'monumento a la madre'}, {'tag': u'Zone', 'word': 'primera avenida'}, {'tag': u'Zone', 'word': 'parque central'}]
# [{'tag': u'City', 'word': 'tegucigalpa'}]
# [{'tag': u'City', 'word': 'tegucigalpa'}, {'tag': u'Col', 'word': 'kennedy'}, {'tag': u'City', 'word': 'distrito central'}]
# [{'tag': u'City', 'word': 'puerto cortes'}, {'tag': u'State', 'word': 'cortes'}, {'tag': u'City', 'word': 'choloma'}, {'tag': u'Col', 'word': 'lopez arellano'}, {'tag': u'Zone', 'word': 'trincheras'}]
# [{'tag': u'City', 'word': 'juticalpa'}, {'tag': u'State', 'word': 'olancho'}, {'tag': u'Country', 'word': 'honduras'}, {'tag': u'City', 'word': 'san esteban'}]
# [{'tag': u'City', 'word': 'el negrito'}, {'tag': u'State', 'word': 'yoro'}, {'tag': u'Zone', 'word': 'la vuelta del sapo'}]
# [{'tag': u'State', 'word': 'colon'}, {'tag': u'City', 'word': 'sonaguera'}]
# [{'tag': u'City', 'word': 'valle de angeles'}, {'tag': u'City', 'word': 'tegucigalpa'}, {'tag': u'City', 'word': 'el chimbo'}, {'tag': u'City', 'word': 'santa lucia'}, {'tag': u'Col', 'word': '20 de noviembre'}]
# [{'tag': u'City', 'word': 'la ceiba'}, {'tag': u'Bar', 'word': 'alvarado'}]
# [{'tag': u'City', 'word': 'tegucigalpa'}]
# [{'tag': u'City', 'word': 'tegucigalpa'}, {'tag': u'City', 'word': 'el chimbo'}, {'tag': u'City', 'word': 'valle de angeles'}, {'tag': u'City', 'word': 'san juancito'}]

# %% [markdown]
# # get Single Entities

# %%
def find_singles(df):
    singles_column =[]
    for ix, article in df.iterrows():
        childs = [ x[0] for x in article.relationships ]
        parents = [ x[1] for x in article.relationships ]
        
        singles =[]
        for entity in article.entities:

            if entity not in childs and entity not in parents:
                singles.append(entity)
                
        singles_column.append(singles)
    
    df.loc[:,"singles"] = singles_column
    df.loc[:,"singles_count"] = df.singles.apply(lambda x: len(x))
    return df

find_singles(articles)[["singles","singles_count" ]].head()
articles.head()
# Out:
#    article_id                                              title  \
# 0           3  [[[Citan, none], [a, none], [11, none], [perso...
# 1           5  [[[DEI, none], [pide, none], [denunciar, none]...
# 2           9  [[[Alcaldia, none], [intensifica, none], [oper...
# 3          11  [[[Pasajeros, none], [asaltantes, none], [acri...
# 4          12  [[[Fallece, none], [comerciante, none], [olanc...
#
#                                              content  \
# 0  [[[SAN, B-City], [PEDRO, I-City], [SULA, I-Cit...
# 1  [[[TEGUCIGALPA, B-City]], [[-, none], [Autorid...
# 2  [[[TEGUCIGALPA, B-City]], [[-, none], [Pese, n...
# 3  [[[PUERTO, B-City], [CORTES, I-City], [,, none...
# 4  [[[JUTICALPA, B-City], [,, none], [Olancho, B-...
#
#                                        relationships  \
# 0  [[{u'tag': u'Col', u'word': u'lomas del carmen...
# 1                                                 []
# 2  [[{u'tag': u'Col', u'word': u'kennedy'}, {u'ta...
# 3  [[{u'tag': u'City', u'word': u'puerto cortes'}...
# 4  [[{u'tag': u'City', u'word': u'juticalpa'}, {u...
#
#                                            full_text  \
# 0  [[[Citan, none], [a, none], [11, none], [perso...
# 1  [[[DEI, none], [pide, none], [denunciar, none]...
# 2  [[[Alcaldia, none], [intensifica, none], [oper...
# 3  [[[Pasajeros, none], [asaltantes, none], [acri...
# 4  [[[Fallece, none], [comerciante, none], [olanc...
#
#                                             entities  \
# 0  [{u'tag': u'City', u'word': u'san pedro sula'}...
# 1       [{u'tag': u'City', u'word': u'tegucigalpa'}]
# 2  [{u'tag': u'City', u'word': u'tegucigalpa'}, {...
# 3  [{u'tag': u'City', u'word': u'puerto cortes'},...
# 4  [{u'tag': u'City', u'word': u'juticalpa'}, {u'...
#
#                                              singles  singles_count
# 0                                                 []              0
# 1       [{u'tag': u'City', u'word': u'tegucigalpa'}]              1
# 2  [{u'tag': u'City', u'word': u'distrito central'}]              1
# 3                                                 []              0
# 4                                                 []              0

# %% [markdown]
# # get Paths

# %%
# get to the root
def getPath( ix, children, parents):
    tag_path = children[ix]["tag"]
    word_path = children[ix]["word"]
    incomplete = 0
    missing_country = 0
    missing_city = 0
    
    if parents[ix] in children:
        p_ix = children.index(parents[ix])
        pt_path, pw_path, incomplete, missing_country, missing_city = getPath(p_ix, children, parents)
        tag_path += "-" + pt_path
        word_path += ", " + pw_path
    else:
        tag_path += "-" + parents[ix]["tag"]
        word_path += ", " + parents[ix]["word"] 
        if parents[ix]["tag"] != "Country":
#             print "--- INCOMPLETE Country---"
            incomplete = 1
            missing_country = 1
        if children[ix]["tag"] not in ["Country","State","City"] and parents[ix]["tag"] != "City":
            incomplete = 1
            missing_city = 1
#             print "--- INCOMPLETE Zone---"
        
    return tag_path, word_path, incomplete, missing_country, missing_city

data = []
for _, article in articles.iterrows():
    children = [ x[0] for x in article.relationships ]
    parents = [ x[1] for x in article.relationships ]

    for ix, entity in enumerate(children):        
        #must be a leaf not part of a branch
        if entity not in parents:
            data.append((article.article_id,) +getPath(ix, children, parents))
    
    #singles
    for entity in article.singles:
        missing_country = 1
        missing_city = 1
        incomplete = 1
        if entity["tag"] == "Country":
            missing_country = 0
            incomplete = 0
        elif entity["tag"] == "City":
            missing_city = 0
        
        data.append((article.article_id,  entity["tag"], entity["word"], incomplete, missing_country, missing_city))

addresses = pd.DataFrame(data,columns=["art_id","shape","address","incomplete", "missing_country", "missing_city"])
addresses.head()
# Out:
#    art_id      shape                               address  incomplete  \
# 0       3   Col-City      lomas del carmen, san pedro sula           1
# 1       3  Zone-City  monumento a la madre, san pedro sula           1
# 2       3  Zone-City       primera avenida, san pedro sula           1
# 3       3  Zone-City        parque central, san pedro sula           1
# 4       5       City                           tegucigalpa           1
#
#    missing_country  missing_city
# 0                1             0
# 1                1             0
# 2                1             0
# 3                1             0
# 4                1             0

# %%
addresses[addresses["missing_country"]==1]
# Out:
#      art_id            shape  \
# 0         3         Col-City
# 1         3        Zone-City
# 2         3        Zone-City
# 3         3        Zone-City
# 4         5             City
# 5         9         Col-City
# 6         9             City
# 7        11   Col-City-State
# 8        11  Zone-City-State
# 9        11       City-State
# 12       13  Zone-City-State
# 13       16       City-State
# 14       20         Col-City
# 15       20             City
# 16       20             City
# 17       20             City
# 18       24         Bar-City
# 19       30             City
# 20       31             City
# 21       31             City
# 22       31             City
# 23       31             City
# 24       32       City-State
# 25       32       City-State
# 26       32       City-State
# 27       32       City-State
# 28       32       City-State
# 29       32       City-State
# 30       32       City-State
# 31       33       City-State
# ..      ...              ...
# 758    2247   Col-City-State
# 759    2257         Bar-City
# 761    2276       City-State
# 762    2276             City
# 763    2276             City
# 764    2276             City
# 765    2286             City
# 767    2286              Col
# 781    2320       City-State
# 782    2320       City-State
# 783    2320       City-State
# 784    2321  Zone-City-State
# 785    2321       City-State
# 786    2321             City
# 787    2322   Col-City-State
# 788    2322              Bar
# 789    2323             Zone
# 790    2323             Zone
# 791    2350        Zone-City
# 792    2350       City-State
# 798    2381         Col-City
# 799    2382       City-State
# 800    2382       City-State
# 823    2410         Col-City
# 824    2410         Col-City
# 825    2415        Zone-City
# 827    2422         Col-City
# 828    2426             City
# 829    2426             Zone
# 831    2426              Col
#
#                                                address  incomplete  \
# 0                     lomas del carmen, san pedro sula           1
# 1                 monumento a la madre, san pedro sula           1
# 2                      primera avenida, san pedro sula           1
# 3                       parque central, san pedro sula           1
# 4                                          tegucigalpa           1
# 5                                 kennedy, tegucigalpa           1
# 6                                     distrito central           1
# 7                lopez arellano, puerto cortes, cortes           1
# 8                    trincheras, puerto cortes, cortes           1
# 9                                      choloma, cortes           1
# 12                la vuelta del sapo, el negrito, yoro           1
# 13                                    sonaguera, colon           1
# 14                        20 de noviembre, tegucigalpa           1
# 15                                    valle de angeles           1
# 16                                           el chimbo           1
# 17                                         santa lucia           1
# 18                                  alvarado, la ceiba           1
# 19                                         tegucigalpa           1
# 20                                         tegucigalpa           1
# 21                                           el chimbo           1
# 22                                    valle de angeles           1
# 23                                        san juancito           1
# 24                                    el jaral, cortes           1
# 25                                 pena blanca, cortes           1
# 26                         santa cruz de yojoa, cortes           1
# 27                                  el caracol, cortes           1
# 28                                 el aguacate, cortes           1
# 29                                   rio lindo, cortes           1
# 30                     la sabana de san manuel, cortes           1
# 31                                 potrerillos, cortes           1
# ..                                                 ...         ...
# 758                        san carlos, choloma, cortes           1
# 759                        barandillas, san pedro sula           1
# 761                                 florencia, caqueta           1
# 762                                             bogota           1
# 763                                             boyaca           1
# 764                                             tolima           1
# 765                                        tegucigalpa           1
# 767                                         santa rosa           1
# 781                                 villanueva, cortes           1
# 782                                   el calan, cortes           1
# 783                             san pedro sula, cortes           1
# 784  penitenciaria nacional marco aurelio soto, tam...           1
# 785                     tegucigalpa, francisco morazan           1
# 786                                     san pedro sula           1
# 787              habitat, amarateca, francisco morazan           1
# 788                                              belen           1
# 789                                            la pena           1
# 790                                            mercado           1
# 791  penitenciaria nacional marco aurelio soto, tamara           1
# 792                             san pedro sula, cortes           1
# 798                            la pradera, comayaguela           1
# 799                                 esparta, atlantida           1
# 800                             ceibita way, atlantida           1
# 823                      cerrito lindo, san pedro sula           1
# 824                   rivera hernandez, san pedro sula           1
# 825              ramon villeda morales, san pedro sula           1
# 827                         21 de octubre, tegucigalpa           1
# 828                                        tegucigalpa           1
# 829                                     villas del sol           1
# 831                                         villanueva           1
#
#      missing_country  missing_city
# 0                  1             0
# 1                  1             0
# 2                  1             0
# 3                  1             0
# 4                  1             0
# 5                  1             0
# 6                  1             0
# 7                  1             0
# 8                  1             0
# 9                  1             0
# 12                 1             0
# 13                 1             0
# 14                 1             0
# 15                 1             0
# 16                 1             0
# 17                 1             0
# 18                 1             0
# 19                 1             0
# 20                 1             0
# 21                 1             0
# 22                 1             0
# 23                 1             0
# 24                 1             0
# 25                 1             0
# 26                 1             0
# 27                 1             0
# 28                 1             0
# 29                 1             0
# 30                 1             0
# 31                 1             0
# ..               ...           ...
# 758                1             0
# 759                1             0
# 761                1             0
# 762                1             0
# 763                1             0
# 764                1             0
# 765                1             0
# 767                1             1
# 781                1             0
# 782                1             0
# 783                1             0
# 784                1             0
# 785                1             0
# 786                1             0
# 787                1             0
# 788                1             1
# 789                1             1
# 790                1             1
# 791                1             0
# 792                1             0
# 798                1             0
# 799                1             0
# 800                1             0
# 823                1             0
# 824                1             0
# 825                1             0
# 827                1             0
# 828                1             0
# 829                1             1
# 831                1             1
#
# [458 rows x 6 columns]

# %% [markdown]
# # Save the Addresses

# %%
addresses.to_csv("../files/expected_addresses.csv", index=False)

# %%
addr_2 = pd.read_csv("../files/expected_addresses.csv")
addr_2.head()
# Out:
#    art_id      shape                               address  incomplete  \
# 0       3   Col-City      lomas del carmen, san pedro sula           1
# 1       3  Zone-City  monumento a la madre, san pedro sula           1
# 2       3  Zone-City       primera avenida, san pedro sula           1
# 3       3  Zone-City        parque central, san pedro sula           1
# 4       5       City                           tegucigalpa           1
#
#    missing_country  missing_city
# 0                1             0
# 1                1             0
# 2                1             0
# 3                1             0
# 4                1             0
